# %%
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from pyproj import transform, Transformer

# %%
output_path = "C:/Users/facci/Desktop"
output_file = "가스사고발생현황.csv"
if not os.path.exists(output_path):
    os.makedirs(output_path)
    
df = pd.DataFrame(columns=['SAFETY_SORT', 'SAFETY_GUBUN', 'SAFETY_CODE', 'SAFETY_NM', 'SAFETY_ADDR', 'SAFETY_PNU'
                           , 'SAFETY_LONG', 'SAFETY_LAT', 'SAFETY_X', 'SAFETY_Y'])

i=0

# %%
serviceKey = '?serviceKey=LPGGTEYH-LPGG-LPGG-LPGG-LPGGTEYH1M'
numOfRows = '&numOfRows=108567'
pageNo = '&pageNo=1'
dataType = '&dataType=XML'

url = 'http://www.safemap.go.kr/openApiService/data/getGasAcdntOccrrncSttusData.do' + serviceKey + numOfRows + pageNo + dataType
print(url)
# Out:
# http://www.safemap.go.kr/openApiService/data/getGasAcdntOccrrncSttusData.do?serviceKey=LPGGTEYH-LPGG-LPGG-LPGG-LPGGTEYH1M&numOfRows=108567&pageNo=1&dataType=XML

# %%
data = urlopen(url).read()
soup = BeautifulSoup(data, "html.parser")
items = soup.find("items")

for item in items.findAll("item"):
    print(item.sgg_cd.text)
    if item.sgg_cd.text == '11440' :
        df.loc[i] = ["accident", '사고안전', '가스사고', "폭발", "서울특별시 마포구 ", item.emd_cd.text
                        , '', '', item.x.text, item.y.text]
    i=i+1
        
df.to_csv(os.path.join(output_path, output_file), encoding='utf-8-sig', index=False)
# Out:
# C:\Users\facci\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 11230
# 48121
# 27170
# 41450
# 42230
# 45790
# 26110
# 11440
# 45111
# 36110
# 42110
# 41590
# 41135
# 11260
# 41650
# 27200
# 27290
# 41131
# 27230
# 42780
# 41360
# 41273
# 41461
# 28710
# 11305
# 26380
# 11620
# 45113
# 45180
# 11305
# 47730
# 31140
# 45740
# 28177
# 11650
# 48127
# 43114
# 11650
# 47130
# 47250
# 42810
# 41271
# 44270
# 31140
# 41461
# 50110
# 42150
# 42110
# 46810
# 30200
# 42190
# 36110
# 41370
# 41610
# 11620
# 45140
# 31710
# 41390
# 43130
# 44800
# 47930
# 41135
# 26710
# 41360
# 42830
# 41115
# 45111
# 45130
# 45130
# 26350
# 47850
# 26290
# 41285
# 41550
# 29140
# 26350
# 30110
# 26260
# 26230
# 45111
# 48121
# 41290
# 41173
# 26440
# 42750
# 42760
# 43130
# 41390
# 26710
# 41360
# 31200
# 11545
# 50110
# 50130
# 31170
# 42110
# 44200
# 11530
# 48129
# 50110
# 11620
# 28237
# 28260
# 50110
# 11215
# 30140
# 28260
# 30140
# 11500
# 41133
# 28200
# 30200
# 27140
# 11620
# 41190
# 46110
# 41250
# 41273
# 41273
# 44133
# 28185
# 41360
# 47930
# 41610
# 29140
# 47230
# 26470
# 47280
# 50130
# 11200
# 26530
# 36110
# 45210
# 41610
# 42110
# 44200
# 42110
# 43112
# 41250
# 41190
# 44133
# 28260
# 28237
# 43130
# 47820
# 50130
# 47830
# 26230
# 26230
# 41670
# 46130
# 11260
# 43750
# 41360
# 41115
# 11230
# 41590
# 11620
# 41610
# 43113
# 41820
# 41281
# 44800
# 28185
# 31140
# 41360
# 26200
# 11350
# 27290
# 42190
# 26440
# 41285
# 48250
# 43130
# 48310
# 26380
# 45140
# 26470
# 31140
# 28237
# 43114
# 41131
# 11260
# 27230
# 28260
# 41113
# 43114
# 41150
# 11590
# 41133
# 11680
# 11560
# 42150
# 47900
# 42720
# 41113
# 41550
# 43150
# 30200
# 11500
# 11530
# 28710
# 41190
# 26380
# 11620
# 11545
# 31140
# 47190
# 11680
# 11590
# 30170
